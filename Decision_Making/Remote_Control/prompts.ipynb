# %% [markdown]
# I'm making a remote controller for a robot, this is the description: Battery powered hand-held device that controls and monitors the state of the SurvBot. Commands are sent and data is received over Bluetooth. The design includes joysticks to control the robot’s velocity, buttons to change the mode it is in and a screen to display the sensor data.
#
# ** The ESP32 module comes with a PCB antenna
#
# I have the schematic and signal block diagram to this query.
# What PCB stack-up do you believe I should use and why?
#
# I have included a link to the schematic and signal block diagram: https://onedrive.live.com/?id=E250AD4F956375AD%2115361&cid=E250AD4F956375AD
# What PCB stack-up do you believe I should use and why?
# ----------------------------------------------------------------
#
#
# I'm making a remote controller for a robot, this is the description: Battery powered hand-held device that controls and monitors the state of the SurvBot. Commands are sent and data is received over Bluetooth. The design includes joysticks to control the robot’s velocity, buttons to change the mode it is in and a screen to display the sensor data.
#
# ** The ESP32 module comes with a PCB antenna.  Just to be clear, I will not be routing anything related to Bluetooth.  The ESP32 module has the RF traces routed into it.  I am soldering the module in its entirety onto the PCB I am designing.
#
# I have the schematic and signal block diagram to this query.
# What PCB stack-up do you believe I should use and why?
# -----------------------------------------------------------------
#
# I'm making a remote controller for a robot, this is the description: Battery powered hand-held device that controls and monitors the state of the SurvBot. Commands are sent and data is received over Bluetooth. The design includes joysticks to control the robot’s velocity, buttons to change the mode it is in and a screen to display the sensor data.
#
# ** The ESP32 module comes with a PCB antenna.  Therefore, the module is the microcontroller with integrated Bluetooth communication. Just to be clear, I will not be routing anything related to Bluetooth.  The ESP32 module has the RF traces routed into it.  I am soldering the module in its entirety onto the PCB I am designing.
#
# Voltage levels: 9V, from the battery, 5V from the USB connector, 3.3 from the buck converter, and 3V from the LDO
# The joysticks send analog signals to the microcontroller.  The microcontroller and display communication via SPI.  The pushbuttons send digital signals to the microcontroller.  The main purpose of the USB connector is to provide a USB interface for the microcontroller.  The USB signals from the connector are sent to a USB-to-UART bridge, which sends and receives information from the microcontroller via UART.
#
#
# I have included the schematic and signal block diagram to this query.
# What PCB stack-up do you believe I should use and why?
#
#
# Okay.  I want the PCB to look like a gaming/flight controller.  Where should I place all the components, namely the screen, USB connector, USB-to-UART bridge, buttons, joysticks, ESP32 module battery?  Left side, right side, top layer, bottom layer, front side, back side etc.
#
# Ah, just realized I wasn't clear about something.  The battery is the primary power source. The 5V from the USB is only there when I am testing/programming the controller and don't want to use up the battery power.  During "normal operation" the USB connector is not connected to anything.  Does this change anything, if so why?
# ----------------------------------------------------------------------
#
# I'm making a remote controller for a robot, this is the description: Battery powered hand-held device that controls and monitors the state of the SurvBot. Commands are sent and data is received over Bluetooth. The design includes joysticks to control the robot’s velocity, buttons to change the mode it is in and a screen to display the sensor data.
#
# ** The ESP32 module comes with a PCB antenna.  Therefore, the module is the microcontroller with integrated Bluetooth communication. Just to be clear, I will not be routing anything related to Bluetooth.  The ESP32 module has the RF traces routed into it. The module in its entirety will be soldered onto the PCB I am designing.
#
# Voltage levels: 9V from the battery, 5V from the USB connector, 3.3 from the buck converter, and 3V from the LDO
# The battery is the primary power source. The USB connector is only there to program the controller and provide power when am testing/programming the controller and don't want to use up the battery power.  During "normal operation" the USB connector is not connected to anything.
#
# The joysticks send analog signals to the microcontroller.  The microcontroller and display communication via SPI.  The pushbuttons send digital signals to the microcontroller.  The main purpose of the USB connector is to provide an interface to program the microcontroller.  The USB signals from the connector are sent to a USB-to-UART bridge, which sends and receives information from the microcontroller via UART.
#
#
# I have included the schematic and signal block diagram to this query.
# What PCB stack-up do you believe I should use and why?
#
#
# Okay.  I want the PCB to look like a gaming/flight controller.  Where should I place all the components, namely the screen, USB connector, USB-to-UART bridge, buttons, joysticks, ESP32 module, battery?  Left side, right side, top layer, bottom layer, front side, back side etc.
#
#
# - Notes from (grok) prompt:
#     - In my original prompt, seems to think that I was tracing the Bluetooth traces, WHICH I AM NOT
#     - Doesn't seem to consider where the USB signals should be placed unless they are mentioned
#     - Need to notify it that the USB connector is only for programming
#     - If I give it a lot of detail, it seems to answer parts of the question with less detail, like what should be in each layer, maybe I should ask it to be detailed like I do with chatGPT
